# %% [markdown]
# <a href="https://colab.research.google.com/github/boramkim0514/KOIPA_AI/blob/main/D49_%EA%B0%95%EC%9B%90%EB%8F%84%EA%B4%80%EA%B4%91%EC%A7%80_%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen, urlretrieve #이미지 파일 저장 용도
import requests #url접속 용도

from bs4 import BeautifulSoup

# %%
url = "https://www.gangwon.to/gwtour/gangwondo_trip/tourist_spot/nature"

# %%
response  = requests.get(url)
data = response.content  #  접속한 웹 사이트 html  코드 가져오기
data
# Out:
# b'\n\r\n\r\n\r\n\r\n\r\n\n\r\n\r\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\n\t<script async src="https://www.googletagmanager.com/gtag/js?id=UA-50072742-1"></script>\n\t<script>\n\t  window.dataLayer = window.dataLayer || [];\n\t  function gtag(){dataLayer.push(arguments);}\n\t  gtag(\'js\', new Date());\n\n\t  gtag(\'config\', \'UA-50072742-1\');\n\t</script>\n\t<title>\xea\xb0\x95\xec\x9b\x90\xea\xb4\x80\xea\xb4\x91</title>\n\t<meta name="Keywords" content="" />\n\t<meta name="Description" content="" />\n\t<meta name="Author" content="" />\n\t<meta charset="utf-8" />\n\t<meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0, maximum-scale=2.0, user-scalable=yes">\n\t<link rel="stylesheet" href="/_common/css/fonts.css" />\n\t<link rel="stylesheet" href="/_common/css/common_new.css" />\n\t<link rel="stylesheet" href="/_common/css/common_style_new.css" />\n\t<link rel="
# ...

# %%
soup = BeautifulSoup(data) # BeautifulSoup으로 data를 element 객채화 시켜서 soup변수에 담아주기
categoryList = soup.find("span", {"class":"category"})  # span  중 class가  cateory  인것만 찾기
categoryList
# Out:
# <span class="category">해변</span>

# %%
categoryListall = soup.find_all("span", {"class":"category"}) 
categoryListall
# Out:
# [<span class="category">해변</span>,
#  <span class="category">섬</span>,
#  <span class="category">공원</span>,
#  <span class="category">해변</span>,
#  <span class="category">해변</span>,
#  <span class="category">해변</span>]

# %%
categoryList = soup.find_all("li")
categoryList

# %%
for cat in categoryList:
    cat_name = cat.select_one("span.category")
    name = fin.select_one("span.storng")

    print("카테고리  : {}".format(cat_name))
    print("관광지명") = cat.select_one("span.storng").text

    print()
# Out:
#   File "<ipython-input-134-591488f868a8>", line 6
#     print("관광지명") = cat.select_one("span.storng").text
#     ^
# SyntaxError: can't assign to function call

# %%
categoryList
# Out:
# [<li><a href="#nolink" onclick="com_searchPopularWord('해변')">#해변</a></li>,
#  <li><a href="#nolink" onclick="com_searchPopularWord('동굴')">#동굴</a></li>,
#  <li><a href="#nolink" onclick="com_searchPopularWord('래프팅')">#래프팅</a></li>,
#  <li><a href="#nolink" onclick="com_searchPopularWord('서핑')">#서핑</a></li>,
#  <li class="facebook"><img alt="페이스북 아이콘" src="/_common/images/ico_login_facebook.png"/><a href="http://www.facebook.com/dialog/oauth?response_type=code&amp;client_id=2026092494342801&amp;redirect_uri=https%3A%2F%2Fwww.gangwon.to%2Fsns%2FsocialLogin%2FfacebookCallback&amp;scope=email&amp;state=fe6564f6-15d7-44ea-b665-86a0145aae82">페이스북 로그인</a></li>,
#  <li class="kakao"><img alt="카카오톡 아이콘" src="/_common/images/ico_login_kakao.png"/><a href="https://kauth.kakao.com/oauth/authorize?response_type=code&amp;client_id=423f544c2e611ac4af6b8c35b7d66ba4&amp;redirect_uri=https%3A%2F%2Fwww.gangwon.to%2Fsns%2FsocialLogin%2FkakaoCallback">카카오 로그인</a></li>,
# ...
